# %%
# Trial for kraken trading

# %%
import ccxt
import json

# %%
f = open('../keys.json','r')
api_keys = json.loads(f.read())
f.close()
kraken_keys = {'api_key':api_keys['krakenapi_keys']['api_key'],'secret_key':api_keys['krakenapi_keys']['secret_key']}

# %%
k = ccxt.kraken({'apiKey':kraken_keys['api_key'], 'secret':kraken_keys['secret_key']})

# %%
pair = 'DOGE/BTC'

# %%
trade = k.create_order(pair,'market','buy',50)
# Out:
# ---------------------------------------------------------------------------
# BadSymbol                                 Traceback (most recent call last)
# <ipython-input-44-083893ee948c> in <module>
# ----> 1 trade = k.create_order(pair,'market','buy',50)
#
# ~/Documents/Sentiment_tool/tweet_activated_crypto_trader/venv/lib/python3.8/site-packages/ccxt/kraken.py in create_order(self, symbol, type, side, amount, price, params)
#     920     def create_order(self, symbol, type, side, amount, price=None, params={}):
#     921         self.load_markets()
# --> 922         market = self.market(symbol)
#     923         request = {
#     924             'pair': market['id'],
#
# ~/Documents/Sentiment_tool/tweet_activated_crypto_trader/venv/lib/python3.8/site-packages/ccxt/base/exchange.py in market(self, symbol)
#    1821         if isinstance(symbol, basestring) and (symbol in self.markets):
#    1822             return self.markets[symbol]
# -> 1823         raise BadSymbol('{} does not have market symbol {}'.format(self.id, symbol))
#    1824
#    1825     def market_ids(self, symbols):
#
# BadSymbol: kraken does not have market symbol XXDGXXBT

# %%
trade
# Out:
# {'id': 'O7KJP4-C6HAY-YHR6JH',
#  'clientOrderId': None,
#  'info': {'descr': {'order': 'buy 50.00000000 XDGXBT @ market'},
#   'txid': ['O7KJP4-C6HAY-YHR6JH']},
#  'timestamp': None,
#  'datetime': None,
#  'lastTradeTimestamp': None,
#  'status': None,
#  'symbol': 'DOGE/BTC',
#  'type': 'market',
#  'timeInForce': None,
#  'postOnly': None,
#  'side': 'buy',
#  'price': None,
#  'stopPrice': None,
#  'cost': None,
#  'amount': 50.0,
#  'filled': None,
#  'average': None,
#  'remaining': None,
#  'fee': None,
#  'trades': None}

# %%
sell = k.create_order(pair,'market','sell',50)
sell
# Out:
# {'id': 'OAMQE6-5KMAF-HS2HZ6',
#  'clientOrderId': None,
#  'info': {'descr': {'order': 'sell 50.00000000 XDGXBT @ market'},
#   'txid': ['OAMQE6-5KMAF-HS2HZ6']},
#  'timestamp': None,
#  'datetime': None,
#  'lastTradeTimestamp': None,
#  'status': None,
#  'symbol': 'DOGE/BTC',
#  'type': 'market',
#  'timeInForce': None,
#  'postOnly': None,
#  'side': 'sell',
#  'price': None,
#  'stopPrice': None,
#  'cost': None,
#  'amount': 50.0,
#  'filled': None,
#  'average': None,
#  'remaining': None,
#  'fee': None,
#  'trades': None}

# %%
k.has
# Out:
# {'loadMarkets': True,
#  'cancelAllOrders': False,
#  'cancelOrder': True,
#  'cancelOrders': False,
#  'CORS': False,
#  'createDepositAddress': True,
#  'createLimitOrder': True,
#  'createMarketOrder': True,
#  'createOrder': True,
#  'deposit': False,
#  'editOrder': 'emulated',
#  'fetchBalance': True,
#  'fetchClosedOrders': True,
#  'fetchCurrencies': True,
#  'fetchDepositAddress': True,
#  'fetchDeposits': True,
#  'fetchL2OrderBook': True,
#  'fetchLedger': True,
#  'fetchMarkets': True,
#  'fetchMyTrades': True,
#  'fetchOHLCV': True,
#  'fetchOpenOrders': True,
#  'fetchOrder': True,
#  'fetchOrderBook': True,
#  'fetchOrderBooks': False,
#  'fetchOrders': False,
#  'fetchOrderTrades': 'emulated',
#  'fetchStatus': 'emulated',
#  'fetchTicker': True,
#  'fetchTickers': True,
#  'fetchTime': True,
#  'fetchTrades': True,
#  'fetchTradingFee': True,
#  'fetchTradingFees': True,
#  'fetchFundingFee': False,
#  'fetchFundingFees': False,
#  'fetchTradingLimits': False,
#  'fetchTransactions': False,
#  'fetchWithdrawals': True,
#  'privateAPI': True,
#  'publicAPI': True,
#  'signIn': False,
#  'withdraw': True,
#  'fetchLedgerEntry': True}

# %%
k.fetchBalance()
# Out:
# {'info': {'XXBT': '0.0002575210', 'XXDG': '0.00000000'},
#  'BTC': {'free': None, 'used': None, 'total': 0.000257521},
#  'DOGE': {'free': None, 'used': None, 'total': 0.0},
#  'free': {'BTC': None, 'DOGE': None},
#  'used': {'BTC': None, 'DOGE': None},
#  'total': {'BTC': 0.000257521, 'DOGE': 0.0}}

# %%
k.fetchTicker('DOGE/BTC')
# Out:
# {'symbol': 'DOGE/BTC',
#  'timestamp': 1612810557550,
#  'datetime': '2021-02-08T18:55:57.550Z',
#  'high': 2.29e-06,
#  'low': 1.58e-06,
#  'bid': 1.78e-06,
#  'bidVolume': None,
#  'ask': 1.79e-06,
#  'askVolume': None,
#  'vwap': 1.888e-06,
#  'open': 2.01e-06,
#  'close': 1.79e-06,
#  'last': 1.79e-06,
#  'previousClose': None,
#  'change': None,
#  'percentage': None,
#  'average': None,
#  'baseVolume': 654119642.9708501,
#  'quoteVolume': 1234.977885928965,
#  'info': {'a': ['0.000001790', '76414', '76414.000'],
#   'b': ['0.000001780', '505114', '505114.000'],
#   'c': ['0.000001790', '1000.00000000'],
#   'v': ['446061358.90007886', '654119642.97085009'],
#   'p': ['0.000001823', '0.000001888'],
#   't': [34192, 51254],
#   'l': ['0.000001580', '0.000001580'],
#   'h': ['0.000002030', '0.000002290'],
#   'o': '0.000002010'}}

# %%
k.fetchTicker('DOGE/USD')
# Out:
# {'symbol': 'DOGE/USD',
#  'timestamp': 1612811240839,
#  'datetime': '2021-02-08T19:07:20.839Z',
#  'high': 0.088,
#  'low': 0.0625,
#  'bid': 0.0788139,
#  'bidVolume': None,
#  'ask': 0.0790711,
#  'askVolume': None,
#  'vwap': 0.076080585,
#  'open': 0.0780181,
#  'close': 0.0790711,
#  'last': 0.0790711,
#  'previousClose': None,
#  'change': None,
#  'percentage': None,
#  'average': None,
#  'baseVolume': 2584850588.693889,
#  'quoteVolume': 196656944.9254255,
#  'info': {'a': ['0.079071100', '61469', '61469.000'],
#   'b': ['0.078813900', '2037', '2037.000'],
#   'c': ['0.079071100', '8491.22625081'],
#   'v': ['1745195423.13124306', '2584850588.69388906'],
#   'p': ['0.074772407', '0.076080585'],
#   't': [109587, 165352],
#   'l': ['0.062500000', '0.062500000'],
#   'h': ['0.085564000', '0.088000000'],
#   'o': '0.078018100'}}

# %%
k.fetchMarkets()
# Out:
# [{'id': 'AAVEAUD',
#   'symbol': 'AAVE/AUD',
#   'base': 'AAVE',
#   'quote': 'AUD',
#   'baseId': 'AAVE',
#   'quoteId': 'ZAUD',
#   'darkpool': False,
#   'info': {'altname': 'AAVEAUD',
#    'wsname': 'AAVE/AUD',
#    'aclass_base': 'currency',
#    'base': 'AAVE',
#    'aclass_quote': 'currency',
#    'quote': 'ZAUD',
#    'lot': 'unit',
#    'pair_decimals': 2,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '0.1'},
#   'altname': 'AAVEAUD',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 2},
#   'limits': {'amount': {'min': 0.1, 'max': 100000000.0},
#    'price': {'min': 0.01, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'AAVEETH',
#   'symbol': 'AAVE/ETH',
#   'base': 'AAVE',
#   'quote': 'ETH',
#   'baseId': 'AAVE',
#   'quoteId': 'XETH',
#   'darkpool': False,
#   'info': {'altname': 'AAVEETH',
#    'wsname': 'AAVE/ETH',
#    'aclass_base': 'currency',
#    'base': 'AAVE',
#    'aclass_quote': 'currency',
#    'quote': 'XETH',
#    'lot': 'unit',
#    'pair_decimals': 4,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '0.05'},
#   'altname': 'AAVEETH',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 4},
#   'limits': {'amount': {'min': 0.05, 'max': 100000000.0},
#    'price': {'min': 0.0001, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'AAVEEUR',
#   'symbol': 'AAVE/EUR',
#   'base': 'AAVE',
#   'quote': 'EUR',
#   'baseId': 'AAVE',
#   'quoteId': 'ZEUR',
#   'darkpool': False,
#   'info': {'altname': 'AAVEEUR',
#    'wsname': 'AAVE/EUR',
#    'aclass_base': 'currency',
#    'base': 'AAVE',
#    'aclass_quote': 'currency',
#    'quote': 'ZEUR',
#    'lot': 'unit',
#    'pair_decimals': 2,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '0.05'},
#   'altname': 'AAVEEUR',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 2},
#   'limits': {'amount': {'min': 0.05, 'max': 100000000.0},
#    'price': {'min': 0.01, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'AAVEGBP',
#   'symbol': 'AAVE/GBP',
#   'base': 'AAVE',
#   'quote': 'GBP',
#   'baseId': 'AAVE',
#   'quoteId': 'ZGBP',
#   'darkpool': False,
#   'info': {'altname': 'AAVEGBP',
#    'wsname': 'AAVE/GBP',
#    'aclass_base': 'currency',
#    'base': 'AAVE',
#    'aclass_quote': 'currency',
#    'quote': 'ZGBP',
#    'lot': 'unit',
#    'pair_decimals': 2,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '0.05'},
#   'altname': 'AAVEGBP',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 2},
#   'limits': {'amount': {'min': 0.05, 'max': 100000000.0},
#    'price': {'min': 0.01, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'AAVEUSD',
#   'symbol': 'AAVE/USD',
#   'base': 'AAVE',
#   'quote': 'USD',
#   'baseId': 'AAVE',
#   'quoteId': 'ZUSD',
#   'darkpool': False,
#   'info': {'altname': 'AAVEUSD',
#    'wsname': 'AAVE/USD',
#    'aclass_base': 'currency',
#    'base': 'AAVE',
#    'aclass_quote': 'currency',
#    'quote': 'ZUSD',
#    'lot': 'unit',
#    'pair_decimals': 2,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '0.05'},
#   'altname': 'AAVEUSD',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 2},
#   'limits': {'amount': {'min': 0.05, 'max': 100000000.0},
#    'price': {'min': 0.01, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'AAVEXBT',
#   'symbol': 'AAVE/BTC',
#   'base': 'AAVE',
#   'quote': 'BTC',
#   'baseId': 'AAVE',
#   'quoteId': 'XXBT',
#   'darkpool': False,
#   'info': {'altname': 'AAVEXBT',
#    'wsname': 'AAVE/XBT',
#    'aclass_base': 'currency',
#    'base': 'AAVE',
#    'aclass_quote': 'currency',
#    'quote': 'XXBT',
#    'lot': 'unit',
#    'pair_decimals': 6,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '0.05'},
#   'altname': 'AAVEXBT',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 6},
#   'limits': {'amount': {'min': 0.05, 'max': 100000000.0},
#    'price': {'min': 1e-06, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'ADAAUD',
#   'symbol': 'ADA/AUD',
#   'base': 'ADA',
#   'quote': 'AUD',
#   'baseId': 'ADA',
#   'quoteId': 'ZAUD',
#   'darkpool': False,
#   'info': {'altname': 'ADAAUD',
#    'wsname': 'ADA/AUD',
#    'aclass_base': 'currency',
#    'base': 'ADA',
#    'aclass_quote': 'currency',
#    'quote': 'ZAUD',
#    'lot': 'unit',
#    'pair_decimals': 5,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '25'},
#   'altname': 'ADAAUD',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 5},
#   'limits': {'amount': {'min': 25.0, 'max': 100000000.0},
#    'price': {'min': 1e-05, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'ADAETH',
#   'symbol': 'ADA/ETH',
#   'base': 'ADA',
#   'quote': 'ETH',
#   'baseId': 'ADA',
#   'quoteId': 'XETH',
#   'darkpool': False,
#   'info': {'altname': 'ADAETH',
#    'wsname': 'ADA/ETH',
#    'aclass_base': 'currency',
#    'base': 'ADA',
#    'aclass_quote': 'currency',
#    'quote': 'XETH',
#    'lot': 'unit',
#    'pair_decimals': 7,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [2, 3],
#    'leverage_sell': [2, 3],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '25'},
#   'altname': 'ADAETH',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 7},
#   'limits': {'amount': {'min': 25.0, 'max': 100000000.0},
#    'price': {'min': 1e-07, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'ADAEUR',
#   'symbol': 'ADA/EUR',
#   'base': 'ADA',
#   'quote': 'EUR',
#   'baseId': 'ADA',
#   'quoteId': 'ZEUR',
#   'darkpool': False,
#   'info': {'altname': 'ADAEUR',
#    'wsname': 'ADA/EUR',
#    'aclass_base': 'currency',
#    'base': 'ADA',
#    'aclass_quote': 'currency',
#    'quote': 'ZEUR',
#    'lot': 'unit',
#    'pair_decimals': 6,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [2, 3],
#    'leverage_sell': [2, 3],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '25'},
#   'altname': 'ADAEUR',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 6},
#   'limits': {'amount': {'min': 25.0, 'max': 100000000.0},
#    'price': {'min': 1e-06, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'ADAGBP',
#   'symbol': 'ADA/GBP',
#   'base': 'ADA',
#   'quote': 'GBP',
#   'baseId': 'ADA',
#   'quoteId': 'ZGBP',
#   'darkpool': False,
#   'info': {'altname': 'ADAGBP',
#    'wsname': 'ADA/GBP',
#    'aclass_base': 'currency',
#    'base': 'ADA',
#    'aclass_quote': 'currency',
#    'quote': 'ZGBP',
#    'lot': 'unit',
#    'pair_decimals': 5,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '25'},
#   'altname': 'ADAGBP',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 5},
#   'limits': {'amount': {'min': 25.0, 'max': 100000000.0},
#    'price': {'min': 1e-05, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'ADAUSD',
#   'symbol': 'ADA/USD',
#   'base': 'ADA',
#   'quote': 'USD',
#   'baseId': 'ADA',
#   'quoteId': 'ZUSD',
#   'darkpool': False,
#   'info': {'altname': 'ADAUSD',
#    'wsname': 'ADA/USD',
#    'aclass_base': 'currency',
#    'base': 'ADA',
#    'aclass_quote': 'currency',
#    'quote': 'ZUSD',
#    'lot': 'unit',
#    'pair_decimals': 6,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [2, 3],
#    'leverage_sell': [2, 3],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '25'},
#   'altname': 'ADAUSD',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 6},
#   'limits': {'amount': {'min': 25.0, 'max': 100000000.0},
#    'price': {'min': 1e-06, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'ADAUSDT',
#   'symbol': 'ADA/USDT',
#   'base': 'ADA',
#   'quote': 'USDT',
#   'baseId': 'ADA',
#   'quoteId': 'USDT',
#   'darkpool': False,
#   'info': {'altname': 'ADAUSDT',
#    'wsname': 'ADA/USDT',
#    'aclass_base': 'currency',
#    'base': 'ADA',
#    'aclass_quote': 'currency',
#    'quote': 'USDT',
#    'lot': 'unit',
#    'pair_decimals': 6,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '25'},
#   'altname': 'ADAUSDT',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 6},
#   'limits': {'amount': {'min': 25.0, 'max': 100000000.0},
#    'price': {'min': 1e-06, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'ADAXBT',
#   'symbol': 'ADA/BTC',
#   'base': 'ADA',
#   'quote': 'BTC',
#   'baseId': 'ADA',
#   'quoteId': 'XXBT',
#   'darkpool': False,
#   'info': {'altname': 'ADAXBT',
#    'wsname': 'ADA/XBT',
#    'aclass_base': 'currency',
#    'base': 'ADA',
#    'aclass_quote': 'currency',
#    'quote': 'XXBT',
#    'lot': 'unit',
#    'pair_decimals': 8,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [2, 3],
#    'leverage_sell': [2, 3],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '25'},
#   'altname': 'ADAXBT',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 8},
#   'limits': {'amount': {'min': 25.0, 'max': 100000000.0},
#    'price': {'min': 1e-08, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'ALGOETH',
#   'symbol': 'ALGO/ETH',
#   'base': 'ALGO',
#   'quote': 'ETH',
#   'baseId': 'ALGO',
#   'quoteId': 'XETH',
#   'darkpool': False,
#   'info': {'altname': 'ALGOETH',
#    'wsname': 'ALGO/ETH',
#    'aclass_base': 'currency',
#    'base': 'ALGO',
#    'aclass_quote': 'currency',
#    'quote': 'XETH',
#    'lot': 'unit',
#    'pair_decimals': 7,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '15'},
#   'altname': 'ALGOETH',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 7},
#   'limits': {'amount': {'min': 15.0, 'max': 100000000.0},
#    'price': {'min': 1e-07, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'ALGOEUR',
#   'symbol': 'ALGO/EUR',
#   'base': 'ALGO',
#   'quote': 'EUR',
#   'baseId': 'ALGO',
#   'quoteId': 'ZEUR',
#   'darkpool': False,
#   'info': {'altname': 'ALGOEUR',
#    'wsname': 'ALGO/EUR',
#    'aclass_base': 'currency',
#    'base': 'ALGO',
#    'aclass_quote': 'currency',
#    'quote': 'ZEUR',
#    'lot': 'unit',
#    'pair_decimals': 5,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [2],
#    'leverage_sell': [2],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '15'},
#   'altname': 'ALGOEUR',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 5},
#   'limits': {'amount': {'min': 15.0, 'max': 100000000.0},
#    'price': {'min': 1e-05, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'ALGOGBP',
#   'symbol': 'ALGO/GBP',
#   'base': 'ALGO',
#   'quote': 'GBP',
#   'baseId': 'ALGO',
#   'quoteId': 'ZGBP',
#   'darkpool': False,
#   'info': {'altname': 'ALGOGBP',
#    'wsname': 'ALGO/GBP',
#    'aclass_base': 'currency',
#    'base': 'ALGO',
#    'aclass_quote': 'currency',
#    'quote': 'ZGBP',
#    'lot': 'unit',
#    'pair_decimals': 5,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '15'},
#   'altname': 'ALGOGBP',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 5},
#   'limits': {'amount': {'min': 15.0, 'max': 100000000.0},
#    'price': {'min': 1e-05, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'ALGOUSD',
#   'symbol': 'ALGO/USD',
#   'base': 'ALGO',
#   'quote': 'USD',
#   'baseId': 'ALGO',
#   'quoteId': 'ZUSD',
#   'darkpool': False,
#   'info': {'altname': 'ALGOUSD',
#    'wsname': 'ALGO/USD',
#    'aclass_base': 'currency',
#    'base': 'ALGO',
#    'aclass_quote': 'currency',
#    'quote': 'ZUSD',
#    'lot': 'unit',
#    'pair_decimals': 5,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [2],
#    'leverage_sell': [2],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '15'},
#   'altname': 'ALGOUSD',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 5},
#   'limits': {'amount': {'min': 15.0, 'max': 100000000.0},
#    'price': {'min': 1e-05, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'ALGOXBT',
#   'symbol': 'ALGO/BTC',
#   'base': 'ALGO',
#   'quote': 'BTC',
#   'baseId': 'ALGO',
#   'quoteId': 'XXBT',
#   'darkpool': False,
#   'info': {'altname': 'ALGOXBT',
#    'wsname': 'ALGO/XBT',
#    'aclass_base': 'currency',
#    'base': 'ALGO',
#    'aclass_quote': 'currency',
#    'quote': 'XXBT',
#    'lot': 'unit',
#    'pair_decimals': 8,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [2],
#    'leverage_sell': [2],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '15'},
#   'altname': 'ALGOXBT',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 8},
#   'limits': {'amount': {'min': 15.0, 'max': 100000000.0},
#    'price': {'min': 1e-08, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'ANTETH',
#   'symbol': 'ANT/ETH',
#   'base': 'ANT',
#   'quote': 'ETH',
#   'baseId': 'ANT',
#   'quoteId': 'XETH',
#   'darkpool': False,
#   'info': {'altname': 'ANTETH',
#    'wsname': 'ANT/ETH',
#    'aclass_base': 'currency',
#    'base': 'ANT',
#    'aclass_quote': 'currency',
#    'quote': 'XETH',
#    'lot': 'unit',
#    'pair_decimals': 6,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '2'},
#   'altname': 'ANTETH',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 6},
#   'limits': {'amount': {'min': 2.0, 'max': 100000000.0},
#    'price': {'min': 1e-06, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'ANTEUR',
#   'symbol': 'ANT/EUR',
#   'base': 'ANT',
#   'quote': 'EUR',
#   'baseId': 'ANT',
#   'quoteId': 'ZEUR',
#   'darkpool': False,
#   'info': {'altname': 'ANTEUR',
#    'wsname': 'ANT/EUR',
#    'aclass_base': 'currency',
#    'base': 'ANT',
#    'aclass_quote': 'currency',
#    'quote': 'ZEUR',
#    'lot': 'unit',
#    'pair_decimals': 4,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '2'},
#   'altname': 'ANTEUR',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 4},
#   'limits': {'amount': {'min': 2.0, 'max': 100000000.0},
#    'price': {'min': 0.0001, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'ANTUSD',
#   'symbol': 'ANT/USD',
#   'base': 'ANT',
#   'quote': 'USD',
#   'baseId': 'ANT',
#   'quoteId': 'ZUSD',
#   'darkpool': False,
#   'info': {'altname': 'ANTUSD',
#    'wsname': 'ANT/USD',
#    'aclass_base': 'currency',
#    'base': 'ANT',
#    'aclass_quote': 'currency',
#    'quote': 'ZUSD',
#    'lot': 'unit',
#    'pair_decimals': 4,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '2'},
#   'altname': 'ANTUSD',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 4},
#   'limits': {'amount': {'min': 2.0, 'max': 100000000.0},
#    'price': {'min': 0.0001, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'ANTXBT',
#   'symbol': 'ANT/BTC',
#   'base': 'ANT',
#   'quote': 'BTC',
#   'baseId': 'ANT',
#   'quoteId': 'XXBT',
#   'darkpool': False,
#   'info': {'altname': 'ANTXBT',
#    'wsname': 'ANT/XBT',
#    'aclass_base': 'currency',
#    'base': 'ANT',
#    'aclass_quote': 'currency',
#    'quote': 'XXBT',
#    'lot': 'unit',
#    'pair_decimals': 8,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '2'},
#   'altname': 'ANTXBT',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 8},
#   'limits': {'amount': {'min': 2.0, 'max': 100000000.0},
#    'price': {'min': 1e-08, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'ATOMAUD',
#   'symbol': 'ATOM/AUD',
#   'base': 'ATOM',
#   'quote': 'AUD',
#   'baseId': 'ATOM',
#   'quoteId': 'ZAUD',
#   'darkpool': False,
#   'info': {'altname': 'ATOMAUD',
#    'wsname': 'ATOM/AUD',
#    'aclass_base': 'currency',
#    'base': 'ATOM',
#    'aclass_quote': 'currency',
#    'quote': 'ZAUD',
#    'lot': 'unit',
#    'pair_decimals': 4,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '1'},
#   'altname': 'ATOMAUD',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 4},
#   'limits': {'amount': {'min': 1.0, 'max': 100000000.0},
#    'price': {'min': 0.0001, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'ATOMETH',
#   'symbol': 'ATOM/ETH',
#   'base': 'ATOM',
#   'quote': 'ETH',
#   'baseId': 'ATOM',
#   'quoteId': 'XETH',
#   'darkpool': False,
#   'info': {'altname': 'ATOMETH',
#    'wsname': 'ATOM/ETH',
#    'aclass_base': 'currency',
#    'base': 'ATOM',
#    'aclass_quote': 'currency',
#    'quote': 'XETH',
#    'lot': 'unit',
#    'pair_decimals': 6,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '1'},
#   'altname': 'ATOMETH',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 6},
#   'limits': {'amount': {'min': 1.0, 'max': 100000000.0},
#    'price': {'min': 1e-06, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'ATOMEUR',
#   'symbol': 'ATOM/EUR',
#   'base': 'ATOM',
#   'quote': 'EUR',
#   'baseId': 'ATOM',
#   'quoteId': 'ZEUR',
#   'darkpool': False,
#   'info': {'altname': 'ATOMEUR',
#    'wsname': 'ATOM/EUR',
#    'aclass_base': 'currency',
#    'base': 'ATOM',
#    'aclass_quote': 'currency',
#    'quote': 'ZEUR',
#    'lot': 'unit',
#    'pair_decimals': 4,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [2],
#    'leverage_sell': [2],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '1'},
#   'altname': 'ATOMEUR',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 4},
#   'limits': {'amount': {'min': 1.0, 'max': 100000000.0},
#    'price': {'min': 0.0001, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'ATOMGBP',
#   'symbol': 'ATOM/GBP',
#   'base': 'ATOM',
#   'quote': 'GBP',
#   'baseId': 'ATOM',
#   'quoteId': 'ZGBP',
#   'darkpool': False,
#   'info': {'altname': 'ATOMGBP',
#    'wsname': 'ATOM/GBP',
#    'aclass_base': 'currency',
#    'base': 'ATOM',
#    'aclass_quote': 'currency',
#    'quote': 'ZGBP',
#    'lot': 'unit',
#    'pair_decimals': 4,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '1'},
#   'altname': 'ATOMGBP',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 4},
#   'limits': {'amount': {'min': 1.0, 'max': 100000000.0},
#    'price': {'min': 0.0001, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'ATOMUSD',
#   'symbol': 'ATOM/USD',
#   'base': 'ATOM',
#   'quote': 'USD',
#   'baseId': 'ATOM',
#   'quoteId': 'ZUSD',
#   'darkpool': False,
#   'info': {'altname': 'ATOMUSD',
#    'wsname': 'ATOM/USD',
#    'aclass_base': 'currency',
#    'base': 'ATOM',
#    'aclass_quote': 'currency',
#    'quote': 'ZUSD',
#    'lot': 'unit',
#    'pair_decimals': 4,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [2],
#    'leverage_sell': [2],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '1'},
#   'altname': 'ATOMUSD',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 4},
#   'limits': {'amount': {'min': 1.0, 'max': 100000000.0},
#    'price': {'min': 0.0001, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'ATOMXBT',
#   'symbol': 'ATOM/BTC',
#   'base': 'ATOM',
#   'quote': 'BTC',
#   'baseId': 'ATOM',
#   'quoteId': 'XXBT',
#   'darkpool': False,
#   'info': {'altname': 'ATOMXBT',
#    'wsname': 'ATOM/XBT',
#    'aclass_base': 'currency',
#    'base': 'ATOM',
#    'aclass_quote': 'currency',
#    'quote': 'XXBT',
#    'lot': 'unit',
#    'pair_decimals': 7,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [2],
#    'leverage_sell': [2],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '1'},
#   'altname': 'ATOMXBT',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 7},
#   'limits': {'amount': {'min': 1.0, 'max': 100000000.0},
#    'price': {'min': 1e-07, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'AUDJPY',
#   'symbol': 'AUD/JPY',
#   'base': 'AUD',
#   'quote': 'JPY',
#   'baseId': 'ZAUD',
#   'quoteId': 'ZJPY',
#   'darkpool': False,
#   'info': {'altname': 'AUDJPY',
#    'wsname': 'AUD/JPY',
#    'aclass_base': 'currency',
#    'base': 'ZAUD',
#    'aclass_quote': 'currency',
#    'quote': 'ZJPY',
#    'lot': 'unit',
#    'pair_decimals': 3,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.2],
#     [50000, 0.16],
#     [100000, 0.12],
#     [250000, 0.08],
#     [500000, 0.04],
#     [1000000, 0]],
#    'fees_maker': [[0, 0.2],
#     [50000, 0.16],
#     [100000, 0.12],
#     [250000, 0.08],
#     [500000, 0.04],
#     [1000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '10'},
#   'altname': 'AUDJPY',
#   'maker': 0.002,
#   'taker': 0.002,
#   'active': True,
#   'precision': {'amount': 8, 'price': 3},
#   'limits': {'amount': {'min': 10.0, 'max': 100000000.0},
#    'price': {'min': 0.001, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'AUDUSD',
#   'symbol': 'AUD/USD',
#   'base': 'AUD',
#   'quote': 'USD',
#   'baseId': 'ZAUD',
#   'quoteId': 'ZUSD',
#   'darkpool': False,
#   'info': {'altname': 'AUDUSD',
#    'wsname': 'AUD/USD',
#    'aclass_base': 'currency',
#    'base': 'ZAUD',
#    'aclass_quote': 'currency',
#    'quote': 'ZUSD',
#    'lot': 'unit',
#    'pair_decimals': 5,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.2],
#     [50000, 0.16],
#     [100000, 0.12],
#     [250000, 0.08],
#     [500000, 0.04],
#     [1000000, 0]],
#    'fees_maker': [[0, 0.2],
#     [50000, 0.16],
#     [100000, 0.12],
#     [250000, 0.08],
#     [500000, 0.04],
#     [1000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '10'},
#   'altname': 'AUDUSD',
#   'maker': 0.002,
#   'taker': 0.002,
#   'active': True,
#   'precision': {'amount': 8, 'price': 5},
#   'limits': {'amount': {'min': 10.0, 'max': 100000000.0},
#    'price': {'min': 1e-05, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'BALETH',
#   'symbol': 'BAL/ETH',
#   'base': 'BAL',
#   'quote': 'ETH',
#   'baseId': 'BAL',
#   'quoteId': 'XETH',
#   'darkpool': False,
#   'info': {'altname': 'BALETH',
#    'wsname': 'BAL/ETH',
#    'aclass_base': 'currency',
#    'base': 'BAL',
#    'aclass_quote': 'currency',
#    'quote': 'XETH',
#    'lot': 'unit',
#    'pair_decimals': 5,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '0.3'},
#   'altname': 'BALETH',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 5},
#   'limits': {'amount': {'min': 0.3, 'max': 100000000.0},
#    'price': {'min': 1e-05, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'BALEUR',
#   'symbol': 'BAL/EUR',
#   'base': 'BAL',
#   'quote': 'EUR',
#   'baseId': 'BAL',
#   'quoteId': 'ZEUR',
#   'darkpool': False,
#   'info': {'altname': 'BALEUR',
#    'wsname': 'BAL/EUR',
#    'aclass_base': 'currency',
#    'base': 'BAL',
#    'aclass_quote': 'currency',
#    'quote': 'ZEUR',
#    'lot': 'unit',
#    'pair_decimals': 2,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '0.3'},
#   'altname': 'BALEUR',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 2},
#   'limits': {'amount': {'min': 0.3, 'max': 100000000.0},
#    'price': {'min': 0.01, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'BALUSD',
#   'symbol': 'BAL/USD',
#   'base': 'BAL',
#   'quote': 'USD',
#   'baseId': 'BAL',
#   'quoteId': 'ZUSD',
#   'darkpool': False,
#   'info': {'altname': 'BALUSD',
#    'wsname': 'BAL/USD',
#    'aclass_base': 'currency',
#    'base': 'BAL',
#    'aclass_quote': 'currency',
#    'quote': 'ZUSD',
#    'lot': 'unit',
#    'pair_decimals': 2,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '0.3'},
#   'altname': 'BALUSD',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 2},
#   'limits': {'amount': {'min': 0.3, 'max': 100000000.0},
#    'price': {'min': 0.01, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'BALXBT',
#   'symbol': 'BAL/BTC',
#   'base': 'BAL',
#   'quote': 'BTC',
#   'baseId': 'BAL',
#   'quoteId': 'XXBT',
#   'darkpool': False,
#   'info': {'altname': 'BALXBT',
#    'wsname': 'BAL/XBT',
#    'aclass_base': 'currency',
#    'base': 'BAL',
#    'aclass_quote': 'currency',
#    'quote': 'XXBT',
#    'lot': 'unit',
#    'pair_decimals': 6,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '0.3'},
#   'altname': 'BALXBT',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 6},
#   'limits': {'amount': {'min': 0.3, 'max': 100000000.0},
#    'price': {'min': 1e-06, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'BATETH',
#   'symbol': 'BAT/ETH',
#   'base': 'BAT',
#   'quote': 'ETH',
#   'baseId': 'BAT',
#   'quoteId': 'XETH',
#   'darkpool': False,
#   'info': {'altname': 'BATETH',
#    'wsname': 'BAT/ETH',
#    'aclass_base': 'currency',
#    'base': 'BAT',
#    'aclass_quote': 'currency',
#    'quote': 'XETH',
#    'lot': 'unit',
#    'pair_decimals': 7,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '30'},
#   'altname': 'BATETH',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 7},
#   'limits': {'amount': {'min': 30.0, 'max': 100000000.0},
#    'price': {'min': 1e-07, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'BATEUR',
#   'symbol': 'BAT/EUR',
#   'base': 'BAT',
#   'quote': 'EUR',
#   'baseId': 'BAT',
#   'quoteId': 'ZEUR',
#   'darkpool': False,
#   'info': {'altname': 'BATEUR',
#    'wsname': 'BAT/EUR',
#    'aclass_base': 'currency',
#    'base': 'BAT',
#    'aclass_quote': 'currency',
#    'quote': 'ZEUR',
#    'lot': 'unit',
#    'pair_decimals': 5,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '30'},
#   'altname': 'BATEUR',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 5},
#   'limits': {'amount': {'min': 30.0, 'max': 100000000.0},
#    'price': {'min': 1e-05, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'BATUSD',
#   'symbol': 'BAT/USD',
#   'base': 'BAT',
#   'quote': 'USD',
#   'baseId': 'BAT',
#   'quoteId': 'ZUSD',
#   'darkpool': False,
#   'info': {'altname': 'BATUSD',
#    'wsname': 'BAT/USD',
#    'aclass_base': 'currency',
#    'base': 'BAT',
#    'aclass_quote': 'currency',
#    'quote': 'ZUSD',
#    'lot': 'unit',
#    'pair_decimals': 5,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '30'},
#   'altname': 'BATUSD',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 5},
#   'limits': {'amount': {'min': 30.0, 'max': 100000000.0},
#    'price': {'min': 1e-05, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'BATXBT',
#   'symbol': 'BAT/BTC',
#   'base': 'BAT',
#   'quote': 'BTC',
#   'baseId': 'BAT',
#   'quoteId': 'XXBT',
#   'darkpool': False,
#   'info': {'altname': 'BATXBT',
#    'wsname': 'BAT/XBT',
#    'aclass_base': 'currency',
#    'base': 'BAT',
#    'aclass_quote': 'currency',
#    'quote': 'XXBT',
#    'lot': 'unit',
#    'pair_decimals': 8,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '30'},
#   'altname': 'BATXBT',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 8},
#   'limits': {'amount': {'min': 30.0, 'max': 100000000.0},
#    'price': {'min': 1e-08, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'BCHAUD',
#   'symbol': 'BCH/AUD',
#   'base': 'BCH',
#   'quote': 'AUD',
#   'baseId': 'BCH',
#   'quoteId': 'ZAUD',
#   'darkpool': False,
#   'info': {'altname': 'BCHAUD',
#    'wsname': 'BCH/AUD',
#    'aclass_base': 'currency',
#    'base': 'BCH',
#    'aclass_quote': 'currency',
#    'quote': 'ZAUD',
#    'lot': 'unit',
#    'pair_decimals': 2,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '0.02'},
#   'altname': 'BCHAUD',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 2},
#   'limits': {'amount': {'min': 0.02, 'max': 100000000.0},
#    'price': {'min': 0.01, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'BCHETH',
#   'symbol': 'BCH/ETH',
#   'base': 'BCH',
#   'quote': 'ETH',
#   'baseId': 'BCH',
#   'quoteId': 'XETH',
#   'darkpool': False,
#   'info': {'altname': 'BCHETH',
#    'wsname': 'BCH/ETH',
#    'aclass_base': 'currency',
#    'base': 'BCH',
#    'aclass_quote': 'currency',
#    'quote': 'XETH',
#    'lot': 'unit',
#    'pair_decimals': 4,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '0.02'},
#   'altname': 'BCHETH',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 4},
#   'limits': {'amount': {'min': 0.02, 'max': 100000000.0},
#    'price': {'min': 0.0001, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'BCHEUR',
#   'symbol': 'BCH/EUR',
#   'base': 'BCH',
#   'quote': 'EUR',
#   'baseId': 'BCH',
#   'quoteId': 'ZEUR',
#   'darkpool': False,
#   'info': {'altname': 'BCHEUR',
#    'wsname': 'BCH/EUR',
#    'aclass_base': 'currency',
#    'base': 'BCH',
#    'aclass_quote': 'currency',
#    'quote': 'ZEUR',
#    'lot': 'unit',
#    'pair_decimals': 2,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [2, 3],
#    'leverage_sell': [2, 3],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '0.02'},
#   'altname': 'BCHEUR',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 2},
#   'limits': {'amount': {'min': 0.02, 'max': 100000000.0},
#    'price': {'min': 0.01, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'BCHGBP',
#   'symbol': 'BCH/GBP',
#   'base': 'BCH',
#   'quote': 'GBP',
#   'baseId': 'BCH',
#   'quoteId': 'ZGBP',
#   'darkpool': False,
#   'info': {'altname': 'BCHGBP',
#    'wsname': 'BCH/GBP',
#    'aclass_base': 'currency',
#    'base': 'BCH',
#    'aclass_quote': 'currency',
#    'quote': 'ZGBP',
#    'lot': 'unit',
#    'pair_decimals': 2,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
# ...
#   'active': True,
#   'precision': {'amount': 8, 'price': 3},
#   'limits': {'amount': {'min': 20.0, 'max': 100000000.0},
#    'price': {'min': 0.001, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'XXRPZUSD',
#   'symbol': 'XRP/USD',
#   'base': 'XRP',
#   'quote': 'USD',
#   'baseId': 'XXRP',
#   'quoteId': 'ZUSD',
#   'darkpool': False,
#   'info': {'altname': 'XRPUSD',
#    'wsname': 'XRP/USD',
#    'aclass_base': 'currency',
#    'base': 'XXRP',
#    'aclass_quote': 'currency',
#    'quote': 'ZUSD',
#    'lot': 'unit',
#    'pair_decimals': 5,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [2, 3, 4, 5],
#    'leverage_sell': [2, 3, 4, 5],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '20'},
#   'altname': 'XRPUSD',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 5},
#   'limits': {'amount': {'min': 20.0, 'max': 100000000.0},
#    'price': {'min': 1e-05, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'XZECXXBT',
#   'symbol': 'ZEC/BTC',
#   'base': 'ZEC',
#   'quote': 'BTC',
#   'baseId': 'XZEC',
#   'quoteId': 'XXBT',
#   'darkpool': False,
#   'info': {'altname': 'ZECXBT',
#    'wsname': 'ZEC/XBT',
#    'aclass_base': 'currency',
#    'base': 'XZEC',
#    'aclass_quote': 'currency',
#    'quote': 'XXBT',
#    'lot': 'unit',
#    'pair_decimals': 5,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [2],
#    'leverage_sell': [2],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '0.1'},
#   'altname': 'ZECXBT',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 5},
#   'limits': {'amount': {'min': 0.1, 'max': 100000000.0},
#    'price': {'min': 1e-05, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'XZECZEUR',
#   'symbol': 'ZEC/EUR',
#   'base': 'ZEC',
#   'quote': 'EUR',
#   'baseId': 'XZEC',
#   'quoteId': 'ZEUR',
#   'darkpool': False,
#   'info': {'altname': 'ZECEUR',
#    'wsname': 'ZEC/EUR',
#    'aclass_base': 'currency',
#    'base': 'XZEC',
#    'aclass_quote': 'currency',
#    'quote': 'ZEUR',
#    'lot': 'unit',
#    'pair_decimals': 3,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [2],
#    'leverage_sell': [2],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '0.1'},
#   'altname': 'ZECEUR',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 3},
#   'limits': {'amount': {'min': 0.1, 'max': 100000000.0},
#    'price': {'min': 0.001, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'XZECZUSD',
#   'symbol': 'ZEC/USD',
#   'base': 'ZEC',
#   'quote': 'USD',
#   'baseId': 'XZEC',
#   'quoteId': 'ZUSD',
#   'darkpool': False,
#   'info': {'altname': 'ZECUSD',
#    'wsname': 'ZEC/USD',
#    'aclass_base': 'currency',
#    'base': 'XZEC',
#    'aclass_quote': 'currency',
#    'quote': 'ZUSD',
#    'lot': 'unit',
#    'pair_decimals': 2,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [2],
#    'leverage_sell': [2],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '0.1'},
#   'altname': 'ZECUSD',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 2},
#   'limits': {'amount': {'min': 0.1, 'max': 100000000.0},
#    'price': {'min': 0.01, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'YFIAUD',
#   'symbol': 'YFI/AUD',
#   'base': 'YFI',
#   'quote': 'AUD',
#   'baseId': 'YFI',
#   'quoteId': 'ZAUD',
#   'darkpool': False,
#   'info': {'altname': 'YFIAUD',
#    'wsname': 'YFI/AUD',
#    'aclass_base': 'currency',
#    'base': 'YFI',
#    'aclass_quote': 'currency',
#    'quote': 'ZAUD',
#    'lot': 'unit',
#    'pair_decimals': 0,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '0.0002'},
#   'altname': 'YFIAUD',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 0},
#   'limits': {'amount': {'min': 0.0002, 'max': 100000000.0},
#    'price': {'min': 1.0, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'YFIETH',
#   'symbol': 'YFI/ETH',
#   'base': 'YFI',
#   'quote': 'ETH',
#   'baseId': 'YFI',
#   'quoteId': 'XETH',
#   'darkpool': False,
#   'info': {'altname': 'YFIETH',
#    'wsname': 'YFI/ETH',
#    'aclass_base': 'currency',
#    'base': 'YFI',
#    'aclass_quote': 'currency',
#    'quote': 'XETH',
#    'lot': 'unit',
#    'pair_decimals': 2,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '0.0002'},
#   'altname': 'YFIETH',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 2},
#   'limits': {'amount': {'min': 0.0002, 'max': 100000000.0},
#    'price': {'min': 0.01, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'YFIEUR',
#   'symbol': 'YFI/EUR',
#   'base': 'YFI',
#   'quote': 'EUR',
#   'baseId': 'YFI',
#   'quoteId': 'ZEUR',
#   'darkpool': False,
#   'info': {'altname': 'YFIEUR',
#    'wsname': 'YFI/EUR',
#    'aclass_base': 'currency',
#    'base': 'YFI',
#    'aclass_quote': 'currency',
#    'quote': 'ZEUR',
#    'lot': 'unit',
#    'pair_decimals': 0,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '0.0002'},
#   'altname': 'YFIEUR',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 0},
#   'limits': {'amount': {'min': 0.0002, 'max': 100000000.0},
#    'price': {'min': 1.0, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'YFIGBP',
#   'symbol': 'YFI/GBP',
#   'base': 'YFI',
#   'quote': 'GBP',
#   'baseId': 'YFI',
#   'quoteId': 'ZGBP',
#   'darkpool': False,
#   'info': {'altname': 'YFIGBP',
#    'wsname': 'YFI/GBP',
#    'aclass_base': 'currency',
#    'base': 'YFI',
#    'aclass_quote': 'currency',
#    'quote': 'ZGBP',
#    'lot': 'unit',
#    'pair_decimals': 0,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '0.0002'},
#   'altname': 'YFIGBP',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 0},
#   'limits': {'amount': {'min': 0.0002, 'max': 100000000.0},
#    'price': {'min': 1.0, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'YFIUSD',
#   'symbol': 'YFI/USD',
#   'base': 'YFI',
#   'quote': 'USD',
#   'baseId': 'YFI',
#   'quoteId': 'ZUSD',
#   'darkpool': False,
#   'info': {'altname': 'YFIUSD',
#    'wsname': 'YFI/USD',
#    'aclass_base': 'currency',
#    'base': 'YFI',
#    'aclass_quote': 'currency',
#    'quote': 'ZUSD',
#    'lot': 'unit',
#    'pair_decimals': 0,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '0.0002'},
#   'altname': 'YFIUSD',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 0},
#   'limits': {'amount': {'min': 0.0002, 'max': 100000000.0},
#    'price': {'min': 1.0, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'YFIXBT',
#   'symbol': 'YFI/BTC',
#   'base': 'YFI',
#   'quote': 'BTC',
#   'baseId': 'YFI',
#   'quoteId': 'XXBT',
#   'darkpool': False,
#   'info': {'altname': 'YFIXBT',
#    'wsname': 'YFI/XBT',
#    'aclass_base': 'currency',
#    'base': 'YFI',
#    'aclass_quote': 'currency',
#    'quote': 'XXBT',
#    'lot': 'unit',
#    'pair_decimals': 4,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.26],
#     [50000, 0.24],
#     [100000, 0.22],
#     [250000, 0.2],
#     [500000, 0.18],
#     [1000000, 0.16],
#     [2500000, 0.14],
#     [5000000, 0.12],
#     [10000000, 0.1]],
#    'fees_maker': [[0, 0.16],
#     [50000, 0.14],
#     [100000, 0.12],
#     [250000, 0.1],
#     [500000, 0.08],
#     [1000000, 0.06],
#     [2500000, 0.04],
#     [5000000, 0.02],
#     [10000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '0.0002'},
#   'altname': 'YFIXBT',
#   'maker': 0.0016,
#   'taker': 0.0026,
#   'active': True,
#   'precision': {'amount': 8, 'price': 4},
#   'limits': {'amount': {'min': 0.0002, 'max': 100000000.0},
#    'price': {'min': 0.0001, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'ZEURZUSD',
#   'symbol': 'EUR/USD',
#   'base': 'EUR',
#   'quote': 'USD',
#   'baseId': 'ZEUR',
#   'quoteId': 'ZUSD',
#   'darkpool': False,
#   'info': {'altname': 'EURUSD',
#    'wsname': 'EUR/USD',
#    'aclass_base': 'currency',
#    'base': 'ZEUR',
#    'aclass_quote': 'currency',
#    'quote': 'ZUSD',
#    'lot': 'unit',
#    'pair_decimals': 5,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.2],
#     [50000, 0.16],
#     [100000, 0.12],
#     [250000, 0.08],
#     [500000, 0.04],
#     [1000000, 0]],
#    'fees_maker': [[0, 0.2],
#     [50000, 0.16],
#     [100000, 0.12],
#     [250000, 0.08],
#     [500000, 0.04],
#     [1000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '5'},
#   'altname': 'EURUSD',
#   'maker': 0.002,
#   'taker': 0.002,
#   'active': True,
#   'precision': {'amount': 8, 'price': 5},
#   'limits': {'amount': {'min': 5.0, 'max': 100000000.0},
#    'price': {'min': 1e-05, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'ZGBPZUSD',
#   'symbol': 'GBP/USD',
#   'base': 'GBP',
#   'quote': 'USD',
#   'baseId': 'ZGBP',
#   'quoteId': 'ZUSD',
#   'darkpool': False,
#   'info': {'altname': 'GBPUSD',
#    'wsname': 'GBP/USD',
#    'aclass_base': 'currency',
#    'base': 'ZGBP',
#    'aclass_quote': 'currency',
#    'quote': 'ZUSD',
#    'lot': 'unit',
#    'pair_decimals': 5,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.2],
#     [50000, 0.16],
#     [100000, 0.12],
#     [250000, 0.08],
#     [500000, 0.04],
#     [1000000, 0]],
#    'fees_maker': [[0, 0.2],
#     [50000, 0.16],
#     [100000, 0.12],
#     [250000, 0.08],
#     [500000, 0.04],
#     [1000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '5'},
#   'altname': 'GBPUSD',
#   'maker': 0.002,
#   'taker': 0.002,
#   'active': True,
#   'precision': {'amount': 8, 'price': 5},
#   'limits': {'amount': {'min': 5.0, 'max': 100000000.0},
#    'price': {'min': 1e-05, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'ZUSDZCAD',
#   'symbol': 'USD/CAD',
#   'base': 'USD',
#   'quote': 'CAD',
#   'baseId': 'ZUSD',
#   'quoteId': 'ZCAD',
#   'darkpool': False,
#   'info': {'altname': 'USDCAD',
#    'wsname': 'USD/CAD',
#    'aclass_base': 'currency',
#    'base': 'ZUSD',
#    'aclass_quote': 'currency',
#    'quote': 'ZCAD',
#    'lot': 'unit',
#    'pair_decimals': 5,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.2],
#     [50000, 0.16],
#     [100000, 0.12],
#     [250000, 0.08],
#     [500000, 0.04],
#     [1000000, 0]],
#    'fees_maker': [[0, 0.2],
#     [50000, 0.16],
#     [100000, 0.12],
#     [250000, 0.08],
#     [500000, 0.04],
#     [1000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '10'},
#   'altname': 'USDCAD',
#   'maker': 0.002,
#   'taker': 0.002,
#   'active': True,
#   'precision': {'amount': 8, 'price': 5},
#   'limits': {'amount': {'min': 10.0, 'max': 100000000.0},
#    'price': {'min': 1e-05, 'max': None},
#    'cost': {'min': 0, 'max': None}}},
#  {'id': 'ZUSDZJPY',
#   'symbol': 'USD/JPY',
#   'base': 'USD',
#   'quote': 'JPY',
#   'baseId': 'ZUSD',
#   'quoteId': 'ZJPY',
#   'darkpool': False,
#   'info': {'altname': 'USDJPY',
#    'wsname': 'USD/JPY',
#    'aclass_base': 'currency',
#    'base': 'ZUSD',
#    'aclass_quote': 'currency',
#    'quote': 'ZJPY',
#    'lot': 'unit',
#    'pair_decimals': 3,
#    'lot_decimals': 8,
#    'lot_multiplier': 1,
#    'leverage_buy': [],
#    'leverage_sell': [],
#    'fees': [[0, 0.2],
#     [50000, 0.16],
#     [100000, 0.12],
#     [250000, 0.08],
#     [500000, 0.04],
#     [1000000, 0]],
#    'fees_maker': [[0, 0.2],
#     [50000, 0.16],
#     [100000, 0.12],
#     [250000, 0.08],
#     [500000, 0.04],
#     [1000000, 0]],
#    'fee_volume_currency': 'ZUSD',
#    'margin_call': 80,
#    'margin_stop': 40,
#    'ordermin': '10'},
#   'altname': 'USDJPY',
#   'maker': 0.002,
#   'taker': 0.002,
#   'active': True,
#   'precision': {'amount': 8, 'price': 3},
#   'limits': {'amount': {'min': 10.0, 'max': 100000000.0},
#    'price': {'min': 0.001, 'max': None},
#    'cost': {'min': 0, 'max': None}}}]

# %%
k.fetchCurrencies()
# Out:
# {'AAVE': {'id': 'AAVE',
#   'code': 'AAVE',
#   'info': {'aclass': 'currency',
#    'altname': 'AAVE',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'AAVE',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'ADA': {'id': 'ADA',
#   'code': 'ADA',
#   'info': {'aclass': 'currency',
#    'altname': 'ADA',
#    'decimals': 8,
#    'display_decimals': 6},
#   'name': 'ADA',
#   'active': True,
#   'fee': None,
#   'precision': 8,
#   'limits': {'amount': {'min': 1e-08, 'max': 100000000.0},
#    'price': {'min': 1e-08, 'max': 100000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 100000000.0}}},
#  'ALGO': {'id': 'ALGO',
#   'code': 'ALGO',
#   'info': {'aclass': 'currency',
#    'altname': 'ALGO',
#    'decimals': 8,
#    'display_decimals': 5},
#   'name': 'ALGO',
#   'active': True,
#   'fee': None,
#   'precision': 8,
#   'limits': {'amount': {'min': 1e-08, 'max': 100000000.0},
#    'price': {'min': 1e-08, 'max': 100000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 100000000.0}}},
#  'ANT': {'id': 'ANT',
#   'code': 'ANT',
#   'info': {'aclass': 'currency',
#    'altname': 'ANT',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'ANT',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'ATOM': {'id': 'ATOM',
#   'code': 'ATOM',
#   'info': {'aclass': 'currency',
#    'altname': 'ATOM',
#    'decimals': 8,
#    'display_decimals': 6},
#   'name': 'ATOM',
#   'active': True,
#   'fee': None,
#   'precision': 8,
#   'limits': {'amount': {'min': 1e-08, 'max': 100000000.0},
#    'price': {'min': 1e-08, 'max': 100000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 100000000.0}}},
#  'ATOM.S': {'id': 'ATOM.S',
#   'code': 'ATOM.S',
#   'info': {'aclass': 'currency',
#    'altname': 'ATOM.S',
#    'decimals': 8,
#    'display_decimals': 6},
#   'name': 'ATOM.S',
#   'active': True,
#   'fee': None,
#   'precision': 8,
#   'limits': {'amount': {'min': 1e-08, 'max': 100000000.0},
#    'price': {'min': 1e-08, 'max': 100000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 100000000.0}}},
#  'BAL': {'id': 'BAL',
#   'code': 'BAL',
#   'info': {'aclass': 'currency',
#    'altname': 'BAL',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'BAL',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'BAT': {'id': 'BAT',
#   'code': 'BAT',
#   'info': {'aclass': 'currency',
#    'altname': 'BAT',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'BAT',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'BCH': {'id': 'BCH',
#   'code': 'BCH',
#   'info': {'aclass': 'currency',
#    'altname': 'BCH',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'BCH',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'CHF': {'id': 'CHF',
#   'code': 'CHF',
#   'info': {'aclass': 'currency',
#    'altname': 'CHF',
#    'decimals': 4,
#    'display_decimals': 2},
#   'name': 'CHF',
#   'active': True,
#   'fee': None,
#   'precision': 4,
#   'limits': {'amount': {'min': 0.0001, 'max': 10000.0},
#    'price': {'min': 0.0001, 'max': 10000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000.0}}},
#  'COMP': {'id': 'COMP',
#   'code': 'COMP',
#   'info': {'aclass': 'currency',
#    'altname': 'COMP',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'COMP',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'CRV': {'id': 'CRV',
#   'code': 'CRV',
#   'info': {'aclass': 'currency',
#    'altname': 'CRV',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'CRV',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'DAI': {'id': 'DAI',
#   'code': 'DAI',
#   'info': {'aclass': 'currency',
#    'altname': 'DAI',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'DAI',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'DASH': {'id': 'DASH',
#   'code': 'DASH',
#   'info': {'aclass': 'currency',
#    'altname': 'DASH',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'DASH',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'DOT': {'id': 'DOT',
#   'code': 'DOT',
#   'info': {'aclass': 'currency',
#    'altname': 'DOT',
#    'decimals': 10,
#    'display_decimals': 8},
#   'name': 'DOT',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'DOT.S': {'id': 'DOT.S',
#   'code': 'DOT.S',
#   'info': {'aclass': 'currency',
#    'altname': 'DOT.S',
#    'decimals': 10,
#    'display_decimals': 8},
#   'name': 'DOT.S',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'EOS': {'id': 'EOS',
#   'code': 'EOS',
#   'info': {'aclass': 'currency',
#    'altname': 'EOS',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'EOS',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'ETH2': {'id': 'ETH2',
#   'code': 'ETH2',
#   'info': {'aclass': 'currency',
#    'altname': 'ETH2',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'ETH2',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'ETH2.S': {'id': 'ETH2.S',
#   'code': 'ETH2.S',
#   'info': {'aclass': 'currency',
#    'altname': 'ETH2.S',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'ETH2.S',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'EUR.HOLD': {'id': 'EUR.HOLD',
#   'code': 'EUR.HOLD',
#   'info': {'aclass': 'currency',
#    'altname': 'EUR.HOLD',
#    'decimals': 4,
#    'display_decimals': 2},
#   'name': 'EUR.HOLD',
#   'active': True,
#   'fee': None,
#   'precision': 4,
#   'limits': {'amount': {'min': 0.0001, 'max': 10000.0},
#    'price': {'min': 0.0001, 'max': 10000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000.0}}},
#  'EUR.M': {'id': 'EUR.M',
#   'code': 'EUR.M',
#   'info': {'aclass': 'currency',
#    'altname': 'EUR.M',
#    'decimals': 4,
#    'display_decimals': 4},
#   'name': 'EUR.M',
#   'active': True,
#   'fee': None,
#   'precision': 4,
#   'limits': {'amount': {'min': 0.0001, 'max': 10000.0},
#    'price': {'min': 0.0001, 'max': 10000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000.0}}},
#  'FIL': {'id': 'FIL',
#   'code': 'FIL',
#   'info': {'aclass': 'currency',
#    'altname': 'FIL',
#    'decimals': 10,
#    'display_decimals': 6},
#   'name': 'FIL',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'FLOW': {'id': 'FLOW',
#   'code': 'FLOW',
#   'info': {'aclass': 'currency',
#    'altname': 'FLOW',
#    'decimals': 10,
#    'display_decimals': 6},
#   'name': 'FLOW',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'FLOW.S': {'id': 'FLOW.S',
#   'code': 'FLOW.S',
#   'info': {'aclass': 'currency',
#    'altname': 'FLOW.S',
#    'decimals': 10,
#    'display_decimals': 6},
#   'name': 'FLOW.S',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'FLOWH': {'id': 'FLOWH',
#   'code': 'FLOWH',
#   'info': {'aclass': 'currency',
#    'altname': 'FLOWH',
#    'decimals': 10,
#    'display_decimals': 6},
#   'name': 'FLOWH',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'FLOWH.S': {'id': 'FLOWH.S',
#   'code': 'FLOWH.S',
#   'info': {'aclass': 'currency',
#    'altname': 'FLOWH.S',
#    'decimals': 10,
#    'display_decimals': 6},
#   'name': 'FLOWH.S',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'GNO': {'id': 'GNO',
#   'code': 'GNO',
#   'info': {'aclass': 'currency',
#    'altname': 'GNO',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'GNO',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'GRT': {'id': 'GRT',
#   'code': 'GRT',
#   'info': {'aclass': 'currency',
#    'altname': 'GRT',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'GRT',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'ICX': {'id': 'ICX',
#   'code': 'ICX',
#   'info': {'aclass': 'currency',
#    'altname': 'ICX',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'ICX',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'KAVA': {'id': 'KAVA',
#   'code': 'KAVA',
#   'info': {'aclass': 'currency',
#    'altname': 'KAVA',
#    'decimals': 8,
#    'display_decimals': 6},
#   'name': 'KAVA',
#   'active': True,
#   'fee': None,
#   'precision': 8,
#   'limits': {'amount': {'min': 1e-08, 'max': 100000000.0},
#    'price': {'min': 1e-08, 'max': 100000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 100000000.0}}},
#  'KAVA.S': {'id': 'KAVA.S',
#   'code': 'KAVA.S',
#   'info': {'aclass': 'currency',
#    'altname': 'KAVA.S',
#    'decimals': 8,
#    'display_decimals': 6},
#   'name': 'KAVA.S',
#   'active': True,
#   'fee': None,
#   'precision': 8,
#   'limits': {'amount': {'min': 1e-08, 'max': 100000000.0},
#    'price': {'min': 1e-08, 'max': 100000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 100000000.0}}},
#  'KEEP': {'id': 'KEEP',
#   'code': 'KEEP',
#   'info': {'aclass': 'currency',
#    'altname': 'KEEP',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'KEEP',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'FEE': {'id': 'KFEE',
#   'code': 'FEE',
#   'info': {'aclass': 'currency',
#    'altname': 'FEE',
#    'decimals': 2,
#    'display_decimals': 2},
#   'name': 'FEE',
#   'active': True,
#   'fee': None,
#   'precision': 2,
#   'limits': {'amount': {'min': 0.01, 'max': 100.0},
#    'price': {'min': 0.01, 'max': 100.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 100.0}}},
#  'KNC': {'id': 'KNC',
#   'code': 'KNC',
#   'info': {'aclass': 'currency',
#    'altname': 'KNC',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'KNC',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'KSM': {'id': 'KSM',
#   'code': 'KSM',
#   'info': {'aclass': 'currency',
#    'altname': 'KSM',
#    'decimals': 10,
#    'display_decimals': 8},
#   'name': 'KSM',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'KSM.S': {'id': 'KSM.S',
#   'code': 'KSM.S',
#   'info': {'aclass': 'currency',
#    'altname': 'KSM.S',
#    'decimals': 10,
#    'display_decimals': 8},
#   'name': 'KSM.S',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'LINK': {'id': 'LINK',
#   'code': 'LINK',
#   'info': {'aclass': 'currency',
#    'altname': 'LINK',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'LINK',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'LSK': {'id': 'LSK',
#   'code': 'LSK',
#   'info': {'aclass': 'currency',
#    'altname': 'LSK',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'LSK',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'MANA': {'id': 'MANA',
#   'code': 'MANA',
#   'info': {'aclass': 'currency',
#    'altname': 'MANA',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'MANA',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'NANO': {'id': 'NANO',
#   'code': 'NANO',
#   'info': {'aclass': 'currency',
#    'altname': 'NANO',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'NANO',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'OMG': {'id': 'OMG',
#   'code': 'OMG',
#   'info': {'aclass': 'currency',
#    'altname': 'OMG',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'OMG',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'OXT': {'id': 'OXT',
#   'code': 'OXT',
#   'info': {'aclass': 'currency',
#    'altname': 'OXT',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'OXT',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'PAXG': {'id': 'PAXG',
#   'code': 'PAXG',
#   'info': {'aclass': 'currency',
#    'altname': 'PAXG',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'PAXG',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'QTUM': {'id': 'QTUM',
#   'code': 'QTUM',
#   'info': {'aclass': 'currency',
#    'altname': 'QTUM',
#    'decimals': 10,
#    'display_decimals': 6},
#   'name': 'QTUM',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'REP': {'id': 'REPV2',
#   'code': 'REP',
#   'info': {'aclass': 'currency',
#    'altname': 'REPV2',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'REP',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'SC': {'id': 'SC',
#   'code': 'SC',
#   'info': {'aclass': 'currency',
#    'altname': 'SC',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'SC',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'SNX': {'id': 'SNX',
#   'code': 'SNX',
#   'info': {'aclass': 'currency',
#    'altname': 'SNX',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'SNX',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'STORJ': {'id': 'STORJ',
#   'code': 'STORJ',
#   'info': {'aclass': 'currency',
#    'altname': 'STORJ',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'STORJ',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'TBTC': {'id': 'TBTC',
#   'code': 'TBTC',
#   'info': {'aclass': 'currency',
#    'altname': 'TBTC',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'TBTC',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'TRX': {'id': 'TRX',
#   'code': 'TRX',
#   'info': {'aclass': 'currency',
#    'altname': 'TRX',
#    'decimals': 8,
#    'display_decimals': 6},
#   'name': 'TRX',
#   'active': True,
#   'fee': None,
#   'precision': 8,
#   'limits': {'amount': {'min': 1e-08, 'max': 100000000.0},
#    'price': {'min': 1e-08, 'max': 100000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 100000000.0}}},
#  'UNI': {'id': 'UNI',
#   'code': 'UNI',
#   'info': {'aclass': 'currency',
#    'altname': 'UNI',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'UNI',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'USD.HOLD': {'id': 'USD.HOLD',
#   'code': 'USD.HOLD',
#   'info': {'aclass': 'currency',
#    'altname': 'USD.HOLD',
#    'decimals': 4,
#    'display_decimals': 2},
#   'name': 'USD.HOLD',
#   'active': True,
#   'fee': None,
#   'precision': 4,
#   'limits': {'amount': {'min': 0.0001, 'max': 10000.0},
#    'price': {'min': 0.0001, 'max': 10000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000.0}}},
#  'USD.M': {'id': 'USD.M',
#   'code': 'USD.M',
#   'info': {'aclass': 'currency',
#    'altname': 'USD.M',
#    'decimals': 4,
#    'display_decimals': 4},
#   'name': 'USD.M',
#   'active': True,
#   'fee': None,
#   'precision': 4,
#   'limits': {'amount': {'min': 0.0001, 'max': 10000.0},
#    'price': {'min': 0.0001, 'max': 10000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000.0}}},
#  'USDC': {'id': 'USDC',
#   'code': 'USDC',
#   'info': {'aclass': 'currency',
#    'altname': 'USDC',
#    'decimals': 8,
#    'display_decimals': 4},
#   'name': 'USDC',
#   'active': True,
#   'fee': None,
#   'precision': 8,
#   'limits': {'amount': {'min': 1e-08, 'max': 100000000.0},
#    'price': {'min': 1e-08, 'max': 100000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 100000000.0}}},
#  'USDT': {'id': 'USDT',
#   'code': 'USDT',
#   'info': {'aclass': 'currency',
#    'altname': 'USDT',
#    'decimals': 8,
#    'display_decimals': 4},
#   'name': 'USDT',
#   'active': True,
#   'fee': None,
#   'precision': 8,
#   'limits': {'amount': {'min': 1e-08, 'max': 100000000.0},
#    'price': {'min': 1e-08, 'max': 100000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 100000000.0}}},
#  'WAVES': {'id': 'WAVES',
#   'code': 'WAVES',
#   'info': {'aclass': 'currency',
#    'altname': 'WAVES',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'WAVES',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'BTC.M': {'id': 'XBT.M',
#   'code': 'BTC.M',
#   'info': {'aclass': 'currency',
#    'altname': 'XBT.M',
#    'decimals': 10,
#    'display_decimals': 8},
#   'name': 'BTC.M',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'ETC': {'id': 'XETC',
#   'code': 'ETC',
#   'info': {'aclass': 'currency',
#    'altname': 'ETC',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'ETC',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'ETH': {'id': 'XETH',
#   'code': 'ETH',
#   'info': {'aclass': 'currency',
#    'altname': 'ETH',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'ETH',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'LTC': {'id': 'XLTC',
#   'code': 'LTC',
#   'info': {'aclass': 'currency',
#    'altname': 'LTC',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'LTC',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'MLN': {'id': 'XMLN',
#   'code': 'MLN',
#   'info': {'aclass': 'currency',
#    'altname': 'MLN',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'MLN',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'REPV1': {'id': 'XREP',
#   'code': 'REPV1',
#   'info': {'aclass': 'currency',
#    'altname': 'REP',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'REPV1',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'XTZ': {'id': 'XTZ',
#   'code': 'XTZ',
#   'info': {'aclass': 'currency',
#    'altname': 'XTZ',
#    'decimals': 8,
#    'display_decimals': 6},
#   'name': 'XTZ',
#   'active': True,
#   'fee': None,
#   'precision': 8,
#   'limits': {'amount': {'min': 1e-08, 'max': 100000000.0},
#    'price': {'min': 1e-08, 'max': 100000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 100000000.0}}},
#  'XTZ.S': {'id': 'XTZ.S',
#   'code': 'XTZ.S',
#   'info': {'aclass': 'currency',
#    'altname': 'XTZ.S',
#    'decimals': 8,
#    'display_decimals': 6},
#   'name': 'XTZ.S',
#   'active': True,
#   'fee': None,
#   'precision': 8,
#   'limits': {'amount': {'min': 1e-08, 'max': 100000000.0},
#    'price': {'min': 1e-08, 'max': 100000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 100000000.0}}},
#  'BTC': {'id': 'XXBT',
#   'code': 'BTC',
#   'info': {'aclass': 'currency',
#    'altname': 'XBT',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'BTC',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'DOGE': {'id': 'XXDG',
#   'code': 'DOGE',
#   'info': {'aclass': 'currency',
#    'altname': 'XDG',
#    'decimals': 8,
#    'display_decimals': 2},
#   'name': 'DOGE',
#   'active': True,
#   'fee': None,
#   'precision': 8,
#   'limits': {'amount': {'min': 1e-08, 'max': 100000000.0},
#    'price': {'min': 1e-08, 'max': 100000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 100000000.0}}},
#  'XLM': {'id': 'XXLM',
#   'code': 'XLM',
#   'info': {'aclass': 'currency',
#    'altname': 'XLM',
#    'decimals': 8,
#    'display_decimals': 5},
#   'name': 'XLM',
#   'active': True,
#   'fee': None,
#   'precision': 8,
#   'limits': {'amount': {'min': 1e-08, 'max': 100000000.0},
#    'price': {'min': 1e-08, 'max': 100000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 100000000.0}}},
#  'XMR': {'id': 'XXMR',
#   'code': 'XMR',
#   'info': {'aclass': 'currency',
#    'altname': 'XMR',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'XMR',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'XRP': {'id': 'XXRP',
#   'code': 'XRP',
#   'info': {'aclass': 'currency',
#    'altname': 'XRP',
#    'decimals': 8,
#    'display_decimals': 5},
#   'name': 'XRP',
#   'active': True,
#   'fee': None,
#   'precision': 8,
#   'limits': {'amount': {'min': 1e-08, 'max': 100000000.0},
#    'price': {'min': 1e-08, 'max': 100000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 100000000.0}}},
#  'ZEC': {'id': 'XZEC',
#   'code': 'ZEC',
#   'info': {'aclass': 'currency',
#    'altname': 'ZEC',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'ZEC',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'YFI': {'id': 'YFI',
#   'code': 'YFI',
#   'info': {'aclass': 'currency',
#    'altname': 'YFI',
#    'decimals': 10,
#    'display_decimals': 5},
#   'name': 'YFI',
#   'active': True,
#   'fee': None,
#   'precision': 10,
#   'limits': {'amount': {'min': 1e-10, 'max': 10000000000.0},
#    'price': {'min': 1e-10, 'max': 10000000000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000000000.0}}},
#  'AUD': {'id': 'ZAUD',
#   'code': 'AUD',
#   'info': {'aclass': 'currency',
#    'altname': 'AUD',
#    'decimals': 4,
#    'display_decimals': 2},
#   'name': 'AUD',
#   'active': True,
#   'fee': None,
#   'precision': 4,
#   'limits': {'amount': {'min': 0.0001, 'max': 10000.0},
#    'price': {'min': 0.0001, 'max': 10000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000.0}}},
#  'CAD': {'id': 'ZCAD',
#   'code': 'CAD',
#   'info': {'aclass': 'currency',
#    'altname': 'CAD',
#    'decimals': 4,
#    'display_decimals': 2},
#   'name': 'CAD',
#   'active': False,
#   'fee': None,
#   'precision': 4,
#   'limits': {'amount': {'min': 0.0001, 'max': 10000.0},
#    'price': {'min': 0.0001, 'max': 10000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000.0}}},
#  'EUR': {'id': 'ZEUR',
#   'code': 'EUR',
#   'info': {'aclass': 'currency',
#    'altname': 'EUR',
#    'decimals': 4,
#    'display_decimals': 2},
#   'name': 'EUR',
#   'active': True,
#   'fee': None,
#   'precision': 4,
#   'limits': {'amount': {'min': 0.0001, 'max': 10000.0},
#    'price': {'min': 0.0001, 'max': 10000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000.0}}},
#  'GBP': {'id': 'ZGBP',
#   'code': 'GBP',
#   'info': {'aclass': 'currency',
#    'altname': 'GBP',
#    'decimals': 4,
#    'display_decimals': 2},
#   'name': 'GBP',
#   'active': False,
#   'fee': None,
#   'precision': 4,
#   'limits': {'amount': {'min': 0.0001, 'max': 10000.0},
#    'price': {'min': 0.0001, 'max': 10000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000.0}}},
#  'JPY': {'id': 'ZJPY',
#   'code': 'JPY',
#   'info': {'aclass': 'currency',
#    'altname': 'JPY',
#    'decimals': 2,
#    'display_decimals': 0},
#   'name': 'JPY',
#   'active': False,
#   'fee': None,
#   'precision': 2,
#   'limits': {'amount': {'min': 0.01, 'max': 100.0},
#    'price': {'min': 0.01, 'max': 100.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 100.0}}},
#  'USD': {'id': 'ZUSD',
#   'code': 'USD',
#   'info': {'aclass': 'currency',
#    'altname': 'USD',
#    'decimals': 4,
#    'display_decimals': 2},
#   'name': 'USD',
#   'active': False,
#   'fee': None,
#   'precision': 4,
#   'limits': {'amount': {'min': 0.0001, 'max': 10000.0},
#    'price': {'min': 0.0001, 'max': 10000.0},
#    'cost': {'min': None, 'max': None},
#    'withdraw': {'min': None, 'max': 10000.0}}}}
