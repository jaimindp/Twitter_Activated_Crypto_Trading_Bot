# %%
# Trial for kraken trading

# %%
import ccxt
import json

# %%
f = open('../keys.json','r')
api_keys = json.loads(f.read())
f.close()
kraken_keys = {'api_key':api_keys['krakenapi_keys']['api_key'],'secret_key':api_keys['krakenapi_keys']['secret_key']}

# %%
k = ccxt.kraken({'apiKey':kraken_keys['api_key'], 'secret':kraken_keys['secret_key']})

# %%
pair = 'DOGE/BTC'

# %%
# trade = k.create_order(pair,'market','buy',50)

# %%
trade

# %%
# sell = k.create_order(pair,'market','sell',50)
sell

# %%
k.has
# Out:
# {'loadMarkets': True,
#  'cancelAllOrders': False,
#  'cancelOrder': True,
#  'cancelOrders': False,
#  'CORS': False,
#  'createDepositAddress': True,
#  'createLimitOrder': True,
#  'createMarketOrder': True,
#  'createOrder': True,
#  'deposit': False,
#  'editOrder': 'emulated',
#  'fetchBalance': True,
#  'fetchClosedOrders': True,
#  'fetchCurrencies': True,
#  'fetchDepositAddress': True,
#  'fetchDeposits': True,
#  'fetchL2OrderBook': True,
#  'fetchLedger': True,
#  'fetchMarkets': True,
#  'fetchMyTrades': True,
#  'fetchOHLCV': True,
#  'fetchOpenOrders': True,
#  'fetchOrder': True,
#  'fetchOrderBook': True,
#  'fetchOrderBooks': False,
#  'fetchOrders': False,
#  'fetchOrderTrades': 'emulated',
#  'fetchStatus': 'emulated',
#  'fetchTicker': True,
#  'fetchTickers': True,
#  'fetchTime': True,
#  'fetchTrades': True,
#  'fetchTradingFee': True,
#  'fetchTradingFees': True,
#  'fetchFundingFee': False,
#  'fetchFundingFees': False,
#  'fetchTradingLimits': False,
#  'fetchTransactions': False,
#  'fetchWithdrawals': True,
#  'privateAPI': True,
#  'publicAPI': True,
#  'signIn': False,
#  'withdraw': True,
#  'fetchLedgerEntry': True}

# %%
k.fetchMyTrades(pair)
# Out:
# [{'id': 'TWYSPU-VVVQI-P5VYEW',
#   'order': 'O7KJP4-C6HAY-YHR6JH',
#   'info': {'ordertxid': 'O7KJP4-C6HAY-YHR6JH',
#    'postxid': 'TKH2SE-M7IF5-CFI7LT',
#    'pair': 'XXDGXXBT',
#    'time': 1612807394.2887,
#    'type': 'buy',
#    'ordertype': 'market',
#    'price': '0.000001860',
#    'cost': '0.000093000',
#    'fee': '0.000000242',
#    'vol': '50.00000000',
#    'margin': '0.000000000',
#    'misc': '',
#    'id': 'TWYSPU-VVVQI-P5VYEW'},
#   'timestamp': 1612807394288,
#   'datetime': '2021-02-08T18:03:14.288Z',
#   'symbol': 'DOGE/BTC',
#   'type': 'market',
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 1.86e-06,
#   'amount': 50.0,
#   'cost': 9.3e-05,
#   'fee': {'cost': 2.42e-07, 'currency': 'BTC'}},
#  {'id': 'TS2KAG-DMP43-PMKPLE',
#   'order': 'OAMQE6-5KMAF-HS2HZ6',
#   'info': {'ordertxid': 'OAMQE6-5KMAF-HS2HZ6',
#    'postxid': 'TKH2SE-M7IF5-CFI7LT',
#    'pair': 'XXDGXXBT',
#    'time': 1612808262.3311,
#    'type': 'sell',
#    'ordertype': 'market',
#    'price': '0.000001820',
#    'cost': '0.000091000',
#    'fee': '0.000000237',
#    'vol': '50.00000000',
#    'margin': '0.000000000',
#    'misc': '',
#    'id': 'TS2KAG-DMP43-PMKPLE'},
#   'timestamp': 1612808262331,
#   'datetime': '2021-02-08T18:17:42.331Z',
#   'symbol': 'DOGE/BTC',
#   'type': 'market',
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 1.82e-06,
#   'amount': 50.0,
#   'cost': 9.1e-05,
#   'fee': {'cost': 2.37e-07, 'currency': 'BTC'}},
#  {'id': 'TDVLI6-QZMNP-373RNE',
#   'order': 'OOVF7I-HV5Y6-DPL5TF',
#   'info': {'ordertxid': 'OOVF7I-HV5Y6-DPL5TF',
#    'postxid': 'TKH2SE-M7IF5-CFI7LT',
#    'pair': 'XXDGXXBT',
#    'time': 1612820340.9372,
#    'type': 'buy',
#    'ordertype': 'market',
#    'price': '0.000001810',
#    'cost': '0.000090500',
#    'fee': '0.000000235',
#    'vol': '50.00000000',
#    'margin': '0.000000000',
#    'misc': '',
#    'id': 'TDVLI6-QZMNP-373RNE'},
#   'timestamp': 1612820340937,
#   'datetime': '2021-02-08T21:39:00.937Z',
#   'symbol': 'DOGE/BTC',
#   'type': 'market',
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 1.81e-06,
#   'amount': 50.0,
#   'cost': 9.05e-05,
#   'fee': {'cost': 2.35e-07, 'currency': 'BTC'}},
#  {'id': 'TYF4DV-YTMUD-EBHUK4',
#   'order': 'O3MEUA-VZG73-HM3WSA',
#   'info': {'ordertxid': 'O3MEUA-VZG73-HM3WSA',
#    'postxid': 'TKH2SE-M7IF5-CFI7LT',
#    'pair': 'XXDGXXBT',
#    'time': 1612820361.2774,
#    'type': 'sell',
#    'ordertype': 'market',
#    'price': '0.000001800',
#    'cost': '0.000090001',
#    'fee': '0.000000234',
#    'vol': '50.00000000',
#    'margin': '0.000000000',
#    'misc': '',
#    'id': 'TYF4DV-YTMUD-EBHUK4'},
#   'timestamp': 1612820361277,
#   'datetime': '2021-02-08T21:39:21.277Z',
#   'symbol': 'DOGE/BTC',
#   'type': 'market',
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 1.8e-06,
#   'amount': 50.0,
#   'cost': 8.999999999999999e-05,
#   'fee': {'cost': 2.34e-07, 'currency': 'BTC'}},
#  {'id': 'TODCZM-CPLML-7OG7JZ',
#   'order': 'OD7XON-RFOPD-6GJ7ED',
#   'info': {'ordertxid': 'OD7XON-RFOPD-6GJ7ED',
#    'postxid': 'TKH2SE-M7IF5-CFI7LT',
#    'pair': 'XXDGXXBT',
#    'time': 1612820553.6576,
#    'type': 'buy',
#    'ordertype': 'market',
#    'price': '0.000001800',
#    'cost': '0.000090000',
#    'fee': '0.000000234',
#    'vol': '50.00000000',
#    'margin': '0.000000000',
#    'misc': '',
#    'id': 'TODCZM-CPLML-7OG7JZ'},
#   'timestamp': 1612820553657,
#   'datetime': '2021-02-08T21:42:33.657Z',
#   'symbol': 'DOGE/BTC',
#   'type': 'market',
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 1.8e-06,
#   'amount': 50.0,
#   'cost': 8.999999999999999e-05,
#   'fee': {'cost': 2.34e-07, 'currency': 'BTC'}},
#  {'id': 'TE2T3S-J3Z4P-DCPJL6',
#   'order': 'OR7LFA-CNAJS-C4TNS2',
#   'info': {'ordertxid': 'OR7LFA-CNAJS-C4TNS2',
#    'postxid': 'TKH2SE-M7IF5-CFI7LT',
#    'pair': 'XXDGXXBT',
#    'time': 1612820568.9575,
#    'type': 'sell',
#    'ordertype': 'market',
#    'price': '0.000001790',
#    'cost': '0.000089500',
#    'fee': '0.000000233',
#    'vol': '50.00000000',
#    'margin': '0.000000000',
#    'misc': '',
#    'id': 'TE2T3S-J3Z4P-DCPJL6'},
#   'timestamp': 1612820568957,
#   'datetime': '2021-02-08T21:42:48.957Z',
#   'symbol': 'DOGE/BTC',
#   'type': 'market',
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 1.79e-06,
#   'amount': 50.0,
#   'cost': 8.950000000000001e-05,
#   'fee': {'cost': 2.33e-07, 'currency': 'BTC'}},
#  {'id': 'TAKUSZ-GYLSL-PZIYW4',
#   'order': 'OWCTCJ-WMZJZ-NTPMYL',
#   'info': {'ordertxid': 'OWCTCJ-WMZJZ-NTPMYL',
#    'postxid': 'TKH2SE-M7IF5-CFI7LT',
#    'pair': 'XXDGXXBT',
#    'time': 1612826492.3863,
#    'type': 'buy',
#    'ordertype': 'market',
#    'price': '0.000001680',
#    'cost': '0.000084000',
#    'fee': '0.000000218',
#    'vol': '50.00000000',
#    'margin': '0.000000000',
#    'misc': '',
#    'id': 'TAKUSZ-GYLSL-PZIYW4'},
#   'timestamp': 1612826492386,
#   'datetime': '2021-02-08T23:21:32.386Z',
#   'symbol': 'DOGE/BTC',
#   'type': 'market',
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 1.68e-06,
#   'amount': 50.0,
#   'cost': 8.4e-05,
#   'fee': {'cost': 2.18e-07, 'currency': 'BTC'}},
#  {'id': 'TEEGLE-5OV5P-KXYWHH',
#   'order': 'O3MLZD-PH6IT-FPMUII',
#   'info': {'ordertxid': 'O3MLZD-PH6IT-FPMUII',
#    'postxid': 'TKH2SE-M7IF5-CFI7LT',
#    'pair': 'XXDGXXBT',
#    'time': 1612826502.7434,
#    'type': 'sell',
#    'ordertype': 'market',
#    'price': '0.000001660',
#    'cost': '0.000083001',
#    'fee': '0.000000216',
#    'vol': '50.00000000',
#    'margin': '0.000000000',
#    'misc': '',
#    'id': 'TEEGLE-5OV5P-KXYWHH'},
#   'timestamp': 1612826502743,
#   'datetime': '2021-02-08T23:21:42.743Z',
#   'symbol': 'DOGE/BTC',
#   'type': 'market',
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 1.66e-06,
#   'amount': 50.0,
#   'cost': 8.3e-05,
#   'fee': {'cost': 2.16e-07, 'currency': 'BTC'}},
#  {'id': 'TCI65Q-EWJ3C-MR2IAK',
#   'order': 'OEBXZA-UZRGG-PFAYEZ',
#   'info': {'ordertxid': 'OEBXZA-UZRGG-PFAYEZ',
#    'postxid': 'TKH2SE-M7IF5-CFI7LT',
#    'pair': 'XXDGXXBT',
#    'time': 1612829979.3331,
#    'type': 'buy',
#    'ordertype': 'market',
#    'price': '0.000001720',
#    'cost': '0.000086000',
#    'fee': '0.000000224',
#    'vol': '50.00000000',
#    'margin': '0.000000000',
#    'misc': '',
#    'id': 'TCI65Q-EWJ3C-MR2IAK'},
#   'timestamp': 1612829979333,
#   'datetime': '2021-02-09T00:19:39.333Z',
#   'symbol': 'DOGE/BTC',
#   'type': 'market',
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 1.72e-06,
#   'amount': 50.0,
#   'cost': 8.6e-05,
#   'fee': {'cost': 2.24e-07, 'currency': 'BTC'}},
#  {'id': 'TDR36V-QCZWM-YMYAKG',
#   'order': 'O2WXTG-L3CLM-GSJAZO',
#   'info': {'ordertxid': 'O2WXTG-L3CLM-GSJAZO',
#    'postxid': 'TKH2SE-M7IF5-CFI7LT',
#    'pair': 'XXDGXXBT',
#    'time': 1612829995.3322,
#    'type': 'sell',
#    'ordertype': 'market',
#    'price': '0.000001710',
#    'cost': '0.000085500',
#    'fee': '0.000000223',
#    'vol': '50.00000000',
#    'margin': '0.000000000',
#    'misc': '',
#    'id': 'TDR36V-QCZWM-YMYAKG'},
#   'timestamp': 1612829995332,
#   'datetime': '2021-02-09T00:19:55.332Z',
#   'symbol': 'DOGE/BTC',
#   'type': 'market',
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 1.71e-06,
#   'amount': 50.0,
#   'cost': 8.549999999999999e-05,
#   'fee': {'cost': 2.23e-07, 'currency': 'BTC'}},
#  {'id': 'T7EK4C-HRBPR-77QKPG',
#   'order': 'OPUAHH-SRHHY-YVM4OR',
#   'info': {'ordertxid': 'OPUAHH-SRHHY-YVM4OR',
#    'postxid': 'TKH2SE-M7IF5-CFI7LT',
#    'pair': 'XXDGXXBT',
#    'time': 1612830184.7549,
#    'type': 'buy',
#    'ordertype': 'market',
#    'price': '0.000001740',
#    'cost': '0.000174000',
#    'fee': '0.000000452',
#    'vol': '100.00000000',
#    'margin': '0.000000000',
#    'misc': '',
#    'id': 'T7EK4C-HRBPR-77QKPG'},
#   'timestamp': 1612830184754,
#   'datetime': '2021-02-09T00:23:04.754Z',
#   'symbol': 'DOGE/BTC',
#   'type': 'market',
#   'side': 'buy',
#   'takerOrMaker': None,
#   'price': 1.74e-06,
#   'amount': 100.0,
#   'cost': 0.000174,
#   'fee': {'cost': 4.52e-07, 'currency': 'BTC'}},
#  {'id': 'TN3EDM-STBLC-QUFMY7',
#   'order': 'OLWYE6-TUJP5-T472DM',
#   'info': {'ordertxid': 'OLWYE6-TUJP5-T472DM',
#    'postxid': 'TKH2SE-M7IF5-CFI7LT',
#    'pair': 'XXDGXXBT',
#    'time': 1612830305.4219,
#    'type': 'sell',
#    'ordertype': 'market',
#    'price': '0.000001720',
#    'cost': '0.000172000',
#    'fee': '0.000000447',
#    'vol': '100.00000000',
#    'margin': '0.000000000',
#    'misc': '',
#    'id': 'TN3EDM-STBLC-QUFMY7'},
#   'timestamp': 1612830305421,
#   'datetime': '2021-02-09T00:25:05.421Z',
#   'symbol': 'DOGE/BTC',
#   'type': 'market',
#   'side': 'sell',
#   'takerOrMaker': None,
#   'price': 1.72e-06,
#   'amount': 100.0,
#   'cost': 0.000172,
#   'fee': {'cost': 4.47e-07, 'currency': 'BTC'}}]

# %%
k.fetchBalance()
# Out:
# {'info': {'XXBT': '0.0232603070', 'XXDG': '0.00000000'},
#  'BTC': {'free': None, 'used': None, 'total': 0.023260307},
#  'DOGE': {'free': None, 'used': None, 'total': 0.0},
#  'free': {'BTC': None, 'DOGE': None},
#  'used': {'BTC': None, 'DOGE': None},
#  'total': {'BTC': 0.023260307, 'DOGE': 0.0}}

# %%
k.fetchTicker('DOGE/BTC')

# %%
k.fetchTicker('DOGE/USD')

# %%
k.fetchMarkets()

# %%
k.fetchCurrencies()
